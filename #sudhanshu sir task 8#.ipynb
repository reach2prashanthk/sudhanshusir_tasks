# %%
import pandas as pd

# %%
#find out average rating on weekly basis keep this is mind that they take two days weekoff
#total working days of each agents
#total query that you've taken
#total feedback you received
#agent name whho has average rating between 3.5 to 4
#agent name who has rating less than 3.5
#agent nasme wh has ating more than 4.5
#average weekly resolution time for each agent
#list of all agents name
#percentage of chat in which they received a feedback
#total contribution hour for each and every agent on weekly basis

#total percentage active hours for a month

# %%
df_per=pd.read_csv('C:\\Users\\prash\\Downloads\\AgentPerformance (2).csv')
df1_log=pd.read_csv("C:\\Users\\prash\\Downloads\\AgentLogingReport (1).csv")

# %%
df_per
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
#df_per['Date']=pd.to_datetime(df_per['Date'])
#df_per.set_index('Date',inplace=True)
df_per.head(20)
# Out:
#            SL No          Agent Name  Total Chats Average Response Time  \
# Date
# 7/30/2022      1        Prerna Singh           11               0:00:38
# 7/30/2022      2       Nandani Gupta           11               0:01:15
# 7/30/2022      3          Ameya Jain           14               0:00:30
# 7/30/2022      4       Mahesh Sarade           14               0:01:04
# 7/30/2022      5              Swati            14               0:01:11
# 7/30/2022      6             Mukesh             9               0:00:34
# 7/30/2022      7     Saikumarreddy N           15               0:00:31
# 7/30/2022      8       Sanjeev Kumar           12               0:00:55
# 7/30/2022      9      Shubham Sharma           13               0:01:31
# 7/30/2022     10        Nishtha Jain           20               0:00:59
# 7/30/2022     11        Manjunatha A           11               0:00:47
# 7/30/2022     12      Khushboo Priya           20               0:01:32
# ...

# %%
#df_per.set_index('Date', inplace=True)
weekly_data = df_per.resample('W-SAT')['Average Rating'].mean()
weekly_data
# Out:
# Date
# 2022-07-02    1.026319
# 2022-07-09    1.349325
# 2022-07-16    1.524167
# 2022-07-23    1.493155
# 2022-07-30    1.601389
# Freq: W-SAT, Name: Average Rating, dtype: float64

# %%
df_per=pd.read_csv('C:\\Users\\prash\\Downloads\\AgentPerformance (2).csv')
df_per.groupby('Agent Name')['Date'].count()
# Out:
# Agent Name
# Abhishek         30
# Aditya           30
# Aditya Shinde    30
# Aditya_iot       30
# Amersh           30
#                  ..
# Uday Mishra      30
# Vasanth P        30
# Vivek            30
# Wasim            30
# Zeeshan          30
# Name: Date, Length: 70, dtype: int64

# %%
##total query that you've taken
df_per.groupby('Agent Name')['Total Chats'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    277
# Aditya_iot       231
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             44
# Wasim            433
# Zeeshan          542
# Name: Total Chats, Length: 70, dtype: int64

# %%
##total feedback you received
df_per.groupby('Agent Name')['Total Feedback'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    153
# Aditya_iot       131
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             20
# Wasim            284
# Zeeshan          335
# Name: Total Feedback, Length: 70, dtype: int64

# %%
#agent name whho has average rating between 3.5 to 4

df_per[(df_per['Average Rating']>3.5) & (df_per['Average Rating']<4)]
# Out:
#       SL No       Date           Agent Name  Total Chats  \
# 4         5  7/30/2022               Swati            14
# 10       11  7/30/2022         Manjunatha A           11
# 76       77  7/29/2022        Prateek _iot             8
# 78       79  7/29/2022        Nandani Gupta           24
# 80       81  7/29/2022        Jaydeep Dixit           27
# ...     ...        ...                  ...          ...
# 1869   1870   7/5/2022  Boktiar Ahmed Bappy           24
# 1874   1875   7/4/2022        Ayushi Mishra           29
# 1941   1942   7/4/2022       Jawala Prakash            6
# 2021   2022   7/2/2022        Aditya Shinde           57
# 2023   2024   7/2/2022     Deepranjan Gupta           52
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 4                  0:01:11                 0:16:33            3.67
# 10                 0:00:47                 0:42:56            3.60
# 76                 0:00:36                 0:10:41            3.75
# ...

# %%
##agent name who has rating less than 3.5
df_per[df_per['Average Rating']<3.5]['Agent Name']
# Out:
# 1            Nandani Gupta
# 19        Hitesh Choudhary
# 20              Sanjeevan
# 21                Anirudh
# 22        Shiva Srivastava
#                ...
# 2155     Sowmiya Sivakumar
# 2156               Nitin M
# 2157                Vivek
# 2158         Ayushi Mishra
# 2159    Chaitra K Hiremath
# Name: Agent Name, Length: 1474, dtype: object

# %%
#agent nasme wh has ating more than 4.5
df_per[df_per['Average Rating']>4.5]['Agent Name']
# Out:
# 2               Ameya Jain
# 3            Mahesh Sarade
# 5                  Mukesh
# 6          Saikumarreddy N
# 7            Sanjeev Kumar
#                ...
# 2100        Shubham Sharma
# 2101         Jaydeep Dixit
# 2102    Shivananda Sonwane
# 2103        Khushboo Priya
# 2104       Hrisikesh Neogi
# Name: Agent Name, Length: 307, dtype: object

# %%
#average weekly resolution time for each agent
#df_per['Date']=pd.to_datetime(df_per['Date'])
df_per.set_index('Date',inplace=True)

# %%
df_per['Average Resolution Time'] = pd.to_timedelta(df_per['Average Resolution Time'])

# %%
df_per['weekly_avg_resolution_time']=df_per.resample('W-SAT')['Average Resolution Time'].mean()
# Out:
#             SL No          Agent Name  Total Chats Average Response Time  \
# Date
# 2022-07-30      1        Prerna Singh           11               0:00:38
# 2022-07-30      2       Nandani Gupta           11               0:01:15
# 2022-07-30      3          Ameya Jain           14               0:00:30
# 2022-07-30      4       Mahesh Sarade           14               0:01:04
# 2022-07-30      5              Swati            14               0:01:11
# ...           ...                 ...          ...                   ...
# 2022-07-01   2156   Sowmiya Sivakumar            0               0:00:00
# 2022-07-01   2157             Nitin M            0               0:00:00
# 2022-07-01   2158              Vivek             0               0:00:00
# 2022-07-01   2159       Ayushi Mishra            0               0:00:00
# 2022-07-01   2160  Chaitra K Hiremath            0               0:00:00
#
#            Average Resolution Time  Average Rating  Total Feedback  \
# Date
# ...

# %%
#list of all agents name

df_per['Agent Name']
# Out:
# Date
# 2022-07-30          Prerna Singh
# 2022-07-30         Nandani Gupta
# 2022-07-30            Ameya Jain
# 2022-07-30         Mahesh Sarade
# 2022-07-30                Swati
#                      ...
# 2022-07-01     Sowmiya Sivakumar
# 2022-07-01               Nitin M
# 2022-07-01                Vivek
# 2022-07-01         Ayushi Mishra
# 2022-07-01    Chaitra K Hiremath
# Name: Agent Name, Length: 2160, dtype: object

# %%
##percentage of chat in which they received a feedback

# %%
df_per['Percentage Feedback']=df_per.apply(lambda i:(i['Total Feedback']/i['Total Chats'])*100 if i['Total Chats']>0 else 0,axis=1)
df_per[['Agent Name','Percentage Feedback']]
# Out:
#                     Agent Name  Percentage Feedback
# Date
# 2022-07-30        Prerna Singh            81.818182
# 2022-07-30       Nandani Gupta            63.636364
# 2022-07-30          Ameya Jain            78.571429
# 2022-07-30       Mahesh Sarade            50.000000
# 2022-07-30              Swati             42.857143
# ...                        ...                  ...
# 2022-07-01   Sowmiya Sivakumar             0.000000
# 2022-07-01             Nitin M             0.000000
# 2022-07-01              Vivek              0.000000
# 2022-07-01       Ayushi Mishra             0.000000
# 2022-07-01  Chaitra K Hiremath             0.000000
#
# [2160 rows x 2 columns]

# %%
##total contribution hour for each and every agent on weekly basis
df1
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
df1['Date']=pd.to_datetime(df1['Date'])
df1['week']=df1['Date'].dt.week
# Out:
# C:\Users\prash\AppData\Local\Temp\ipykernel_10644\603121239.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df1['week']=df1['Date'].dt.week

# %%
df1['Login Time']=pd.to_datetime(df1['Login Time'])
df1['Logout Time']=pd.to_datetime(df1['Logout Time'])

# %%
df1.groupby([df1['Agent'],df1['Date'].dt.week])['Duration'].sum()
# Out:
# C:\Users\prash\AppData\Local\Temp\ipykernel_10644\3410587355.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df1.groupby([df1['Agent'],df1['Date'].dt.week])['Duration'].sum()
# Agent          Date
# Aditya Shinde  30                                               00:02:10
# Aditya_iot     29                               01:57:3102:06:4602:01:26
#                30       02:12:0500:49:4600:04:2002:14:4301:57:4702:19:28
# Amersh         30                       00:02:4002:54:5200:05:2900:00:49
# Ameya Jain     29      00:44:4000:07:2404:01:1001:57:5906:00:5704:37:...
#                                              ...
# Tarun          26                                              514:08:20
# Wasim          29      00:00:5500:02:0005:32:3000:05:3006:03:0000:00:...
#                30      07:19:5000:02:2006:12:0705:24:0500:01:5003:45:...
# ...
