# %%
task1: in past whatever the questions givn with respect to list, dict,set string try to create separate class for each and everything and reconstruct your code for all segmant and submit
    
    number1: always use exception handling
        use logging as well
        
    reformat the code and su bmit  to sudhanshu@ineuron.ai and sunny.savita@ineuron.ai

# %%
import logging
logging.basicConfig(filename='loginfo.log',level=logging.INFO,format='%(asctime)s  %(levelname)s %(name)s %(message)s')
#class string

class string_task:
    #extract string
    def string_extract(self,ext_string):
        loggign.info('were about to extract string from index 1 to index 300 with a jump of 3')
        self.ext_string=ext_string
        
    try:
        if len(ext_string)==0:
            raise ValueError('empty string')
            logging.error(e)
        else:
            str=ext_string[::3]
            logging.info('were reversing our string')
    except Exception as e:
        logging.exception(e)
        
        
#reverse string
  
    def string_reverse(self,rev_string):
        logging.info('we are about to reverse string')
        self.rev_string=rev_string
        logging.info('were about to reverse string')
        try:
            if len(rev_string)==0:
                raise ValueError('empty string')
                logging.error('empty string')
            else:
                str=rev_string[::-1]
                logging.info('reversed string %s',str)
                return str
        except Exception as e:
            logging.exception(e)
            
            
#split string
      
    def string_split(self,string):
        logging.info('we are about to split string')
        self.string=string
        try:
            if len(string)==0:
                raise ValueError('empty string')
                
            else:
                str=string.upper()
                str1=str.split()
                logging.info('splitted string is %s ',str1)
                return str1
        except Exception as e:
            logging.exception(e)


#lower string
    def string_lower(self,string_lower):
        logging.info('we are about to lower the string')
        self.string_lower=string_lower
        
        try:
            if len(string_lower)==0:
                raise ValueError('empty string')
                logging.error('empty string')
            else:
                str=string_lower.lower()
                logging.info('the lower string is %s ',str)
                return str
    
        except Exception as e:
            loggign.exception(e)
            

    def string_caps(self,cstring):
        logging.info('we are about to captitalize string')
        self.cstring=cstring
        
    try:
        if len(cstring)==0:
            raise ValueError('empty string')
            logging.error('the capitalized string is %s', str)
        else:
            str=cstring.title()
            logging.info('the title string is %s',str)
    except Exception as e:
        logging.exception(e)
        

#class for list
class list_string:
    logging.info('log for list class')
    
    def list_reverse(self,list_rev):
        logging.info('we are about to reverse list')
        self.list_rev=list_rev
        try:
            if len(list_rev)==0:
                raise ValueError('list is empty')
                logging.error('list is empty')
            else:
                list_rev=list_rev.reverse()
                loggign.info('reverse list is %s',list_rev)
                return list_rev
        except Exception as e:
            logging.exception(e)
            
#extract numbers from list

    def extract_int(self,l1,num):
        logging.info(' we are about find the number')
        self.l1=l1
        self.num=num
        try:
            if len(l1)==0 or num==0:
                raise ValueError('list is empty or number is 0')
                logging.error('list is empty or number is 0')
            elif type(num)!=int:
                raise TypeError('number is not integer')
                logging.error('number is not 0 ')
            else:
                for i in l1:
                    if type(i)==num:
                        logging.info('the discarded number is found in %s',i)
                        return i
                else:
                    logging.info('number not foud')
        except Exception as e:
            logging.exception(e)
            
    
 #extract list from list
     
    def extract_list(self,lst1):
        logging.info('we are abput to extract  the list')
        self.lst1=lst1
        
        try:
            if len(lst1)==0:
                raise ValueError('list is empty')
                logging.error('list is empty')
            else:
                for i in lst1:
                    if type(i)==list:
                        logging.info('the list is with in the list %s ',i )
                        return i
        except Exception as e:
            logging.exception(e)
            
#extract dict in list

   
    def extract_keylist(self,list_key) :
        logging.info('we are about to extract the list')
        self.list_key=list_key
        try:
            if len(list_key)==0:
                raise ValueError('list is empty')
                logging.error('list is empty')
            else:
                l=[]
                for i in list_key:
                    if type(i)==dict:
                        for k in i.keys():
                            logging.info('the key is %s',k)
                            l.append(k)
                return l
        except Exception as e:
            logging.exception(e)
#extract all integer from list

    def ext_allint(self,list2):
        logging.info('we are about extract the list')
        self.list2=list2
        try:
            if len(list2)==0:
                raise ValueError('list is empty')
                logging.error('list is empty')
            else:
                l=[]
                for i in list2:
                    if type(i)==tuple or type(i)==list or type(i)==set:
                        for j in i:
                            if type(j)==int:
                                logging.info('the int values  is %s',j)
                                l.append(j)
                if type(i)==dict:
                    for k,v in i.items():
                        if type(k)==int or type(v)==int:
                            l.append(k)
                            l.append(v)
                return l
        except Exception as e:
            logging.exception(e)
            
            
#extract all odd numbers from list

    def extract_num(self,list3):
        self.list3=list3
        
        try:
            if len(list3)==0:
                logging.error('list is empty')
            else:
                l=[]
                for i in list3:
                    if type(i)==tuple or type(i)==list or type(i)==set:
                        for j in i:
                            if type(j)==int:
                                if (j%2)!=0:
                                    logging.info('the int value is',j)
                                    l.append(j)
                    if type(i)==dict:
                        logging.info('the value dict')
                        for k,v in i.items():
                            if type(k)==int or type(v)==int:
                                
                                if (k % 2)!=0 or (v % 2)!=0:
                                    logging.info(' the int  value is %s',j)
                                    l.append(k)
                                    l.append(v)
                return l
        
        except Exception as e:
            logging.exception(e)
# Out:
# ERROR:root:name 'ext_string' is not defined
# Traceback (most recent call last):
#   File "C:\Users\prash\AppData\Local\Temp\ipykernel_5468\3322077501.py", line 12, in string_task
#     if len(ext_string)==0:
# NameError: name 'ext_string' is not defined
# ERROR:root:name 'cstring' is not defined
# Traceback (most recent call last):
#   File "C:\Users\prash\AppData\Local\Temp\ipykernel_5468\3322077501.py", line 81, in string_task
#     if len(cstring)==0:
# NameError: name 'cstring' is not defined
